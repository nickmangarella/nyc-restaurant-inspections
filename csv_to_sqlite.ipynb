# %%
import pandas as pd

# %%
df = pd.read_csv("static/data/NYC_Restaurant_Inspection_Results_Clean2020.csv")
df.head()
# Out:
#       CAMIS                           DBA           BORO BUILDING  \
# 0  50090691   SALIM KENNEDY FRIED CHICKEN         Queens    16614
# 1  50095392               HOPE TO SEE YOU         Queens   133-42
# 2  50033575      JACQUES TORRES ICE CREAM      Manhattan       89
# 3  50089342  REGAL CINEMAS ESSEX CROSSING      Manhattan      129
# 4  50033875                      ARIANA'S  Staten Island       60
#
#                 STREET  ZIPCODE       PHONE              CUISINE DESCRIPTION  \
# 0         HILLSIDE AVE  11432.0  7183744616                      Bangladeshi
# 1            39 AVENUE  11354.0  7188881669                          Chinese
# 2     EAST   42 STREET  10017.0  2129837353  Ice Cream, Gelato, Yogurt, Ices
# 3      DELANCEY STREET  10002.0  2124755768                         American
# 4  SOUTH BRIDGE STREET  10309.0  7189678500                          Italian
#
#   INSPECTION DATE                                           ACTION  ...  \
# ...

# %%
import sqlite3

# %%
conn = sqlite3.connect('NYC_Restaurant_Inspection_Results_Clean2020.sqlite')
df.to_sql('NYC_Restaurant_Inspection_Results_Clean2020', conn, if_exists='replace', index=True)
# Out:
# C:\Users\jcg\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py:2605: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %%
pd.read_sql('select * from NYC_Restaurant_Inspection_Results_Clean2020', conn)
# Out:
#        index     CAMIS                           DBA           BORO BUILDING  \
# 0          0  50090691   SALIM KENNEDY FRIED CHICKEN         Queens    16614
# 1          1  50095392               HOPE TO SEE YOU         Queens   133-42
# 2          2  50033575      JACQUES TORRES ICE CREAM      Manhattan       89
# 3          3  50089342  REGAL CINEMAS ESSEX CROSSING      Manhattan      129
# 4          4  50033875                      ARIANA'S  Staten Island       60
# ...      ...       ...                           ...            ...      ...
# 30638  30638  50086667             JJ'S ASIAN FUSION         Queens    37-05
# 30639  30639  41691396                         SAM'S         Queens    89-06
# 30640  30640  50102250         XOXO KITCHEN & BAKERY         Queens      883
# 30641  30641  41683337           AVLEE GREEK KITCHEN       Brooklyn      349
# 30642  30642  50016747                   SARKU JAPAN          Bronx      815
#
# ...
